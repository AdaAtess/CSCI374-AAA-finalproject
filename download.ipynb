# %% [markdown]
# # Download Images from Instagram Python Script

# %%
# Use instaloader to download images from Instagram
from instaloader import Instaloader, Profile
# Create an instance of Instaloader class
L = Instaloader()

# %%
# Identify the profile to scrape from
PROFILE = "yikyakyeo"
# Get the profile context from profile
profile = Profile.from_username(L.context, PROFILE)

# %%
# Get the posts from the profile sorted the number of likes
posts_sorted_by_likes = sorted(profile.get_posts(), key=lambda p: p.likes, reverse=True)

# %%
# Download all the posts and store them into a folder named after the profile
for post in posts_sorted_by_likes:
    L.download_post(post, PROFILE)
# Out:
# yikyakyeo/2022-09-28_00-10-31_UTC_1.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_2.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_3.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_4.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_5.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_6.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_7.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_8.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_9.jpg exists yikyakyeo/2022-09-28_00-10-31_UTC_10.jpg exists [Me when my yikyakyeo post is …] unchanged json
# yikyakyeo/2022-09-15_14-41-34_UTC_1.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_2.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_3.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_4.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_5.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_6.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_7.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_8.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_9.jpg exists yikyakyeo/2022-09-15_14-41-34_UTC_10.jpg exists json
# ...
